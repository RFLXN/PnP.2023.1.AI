# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("data/young_survey.csv")

data = df[["Branded clothing", "Healthy eating", "Musical instruments", "New environment", "Prioritising workload", "Spending on looks", "Workaholism", "Writing", "Writing notes"]]

sns.heatmap(data=data.corr())
# Out:
# <Axes: >
